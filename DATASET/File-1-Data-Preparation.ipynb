# %% [markdown]
# <div style="text-align: center; background-color: #856ff8; padding: 10px;">
#     <h2 style="font-weight: bold;">OUTLINE</h2>
# </div>

# %% [markdown]
# - Importing Various Modules
# - Loading Dataset
# - Data Wrangling
#     - Computing the size of DataFrame
#     - Enlist the Column Labels
#     - Summary Statistics for Numerical Columns
#     - Generating Basic Information of Attributes
#     - Enlisting Numerical Features
#     - Enlisting Categorical Features
#     - Handling Columns
# - Save Dataframe to CSV File

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">IMPORTING VARIOUS MODULES</h2>
# </div>

# %%
#Library for data manipulation
import pandas as pd
import numpy as np

#librabry settings to display whole data
pd.set_option("display.max.columns", None)
pd.set_option("display.max.rows", None)

#library for data visualisation
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#librabry settings for data visualisation
sns.set(style="white",font_scale=1.5)
sns.set(rc={"axes.facecolor":"#FFFAF0","figure.facecolor":"#FFFAF0"})
sns.set_context("poster",font_scale = .7)

#library to warnigs
import warnings
warnings.filterwarnings("always")
warnings.filterwarnings("ignore")

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">LOADING DATASET</h2>
# </div>

# %%
apps_data = pd.read_csv(r"file1_googleplaystore.csv")

# %%
apps_data.head().style.set_properties(**{'background-color':'#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# ...

# %%
apps_data.tail().style.set_properties(**{'background-color':'#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">DATA WRANGLING</h2>
# </div>

# %% [markdown]
# ## <span style='color:black'> 1] COMPUTING SIZE OF DATASET </span>

# %%
# Print the shape of the DataFrame
print("The shape of data frame:", apps_data.shape)
# Print the length (number of rows) of the DataFrame
print("Number of Rows in the dataframe:", len(apps_data))
# Print the number of columns in the DataFrame
print("Number of Columns in the dataframe:", len(apps_data.columns))
# Out:
# The shape of data frame: (10841, 13)
# Number of Rows in the dataframe: 10841
# Number of Columns in the dataframe: 13

# %% [markdown]
# ## 2] Enlist the Column Labels

# %%
for col in apps_data.columns:
    print(col)
    
print('\n')
print("Columns size:", apps_data.shape[1])
# Out:
# App
# Category
# Rating
# Reviews
# Size
# Installs
# Type
# Price
# Content Rating
# Genres
# Last Updated
# Current Ver
# Android Ver
#
#
# Columns size: 13

# %% [markdown]
# ## 3] SUMMARY STATISTICS FOR NUMERICAL COLUMNS

# %%
apps_data.describe(include='all').T
# Out:
#                  count unique                 top   freq      mean       std  \
# App              10841   9660              ROBLOX      9       NaN       NaN
# Category         10841     34              FAMILY   1972       NaN       NaN
# Rating          9367.0    NaN                 NaN    NaN  4.193338  0.537431
# Reviews          10841   6002                   0    596       NaN       NaN
# Size             10841    462  Varies with device   1695       NaN       NaN
# Installs         10841     22          1,000,000+   1579       NaN       NaN
# Type             10840      3                Free  10039       NaN       NaN
# Price            10841     93                   0  10040       NaN       NaN
# Content Rating   10840      6            Everyone   8714       NaN       NaN
# Genres           10841    120               Tools    842       NaN       NaN
# Last Updated     10841   1378      August 3, 2018    326       NaN       NaN
# ...

# %% [markdown]
# ### <font color=red>Inference:</font>
#
# - The described method will help to see how data has been spread for numerical values.
# - We can clearly see the minimum value, mean values, different percentile values, and maximum values.

# %% [markdown]
# ## 4] GENERATING BASIC INFORMATION OF ATTRIBUTES

# %%
apps_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ### <font color=red>Inference:</font>
# 1. The data has 12 object and 1 numeric feature
# 2. We need to convert (Reviews & Size & Installs & Price) to int
# 3. We need to Change Last update into a datetime column

# %% [markdown]
# ## 5] Enlist the Numeric Columns

# %%
apps_data.select_dtypes(np.number).sample(5).style.set_properties(**{'background-color':'#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_ec1c5_row0_col0, #T_ec1c5_row1_col0, #T_ec1c5_row2_col0, #T_ec1c5_row3_col0, #T_ec1c5_row4_col0 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_ec1c5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec1c5_level0_row0" class="row_heading level0 row0" >8398</th>
#       <td id="T_ec1c5_row0_col0" class="data row0 col0" >4.400000</td>
#     </tr>
#     <tr>
#       <th id="T_ec1c5_level0_row1" class="row_heading level0 row1" >1780</th>
#       <td id="T_ec1c5_row1_col0" class="data row1 col0" >4.600000</td>
#     </tr>
#     <tr>
#       <th id="T_ec1c5_level0_row2" class="row_heading level0 row2" >1261</th>
#       <td id="T_ec1c5_row2_col0" class="data row2 col0" >4.800000</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### <font color=red>Inference:</font>
#
# 1. There is only 1 Numerical Attributes in the dataset.

# %% [markdown]
# ## 6] ENLISTING CATEGORICAL FEATURES

# %%
apps_data.select_dtypes(include=['O']).sample(5).style.set_properties(**{'background-color':'#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ### <font color=red>Inference:</font>
#
# 1. We need to convert (Reviews & Size & Installs & Price) to int

# %% [markdown]
# ## 4] HANDLING COLUMNS

# %% [markdown]
# ### 4.1] Reviews

# %%
# Calculate the number of rows in the 'Reviews' column where the values are numeric.
apps_data['Reviews'].str.isnumeric().sum()
# Out:
# 10840

# %%
apps_data_copy = apps_data.copy()

# %%
# Create a DataFrame containing rows with non-numeric values in the 'Reviews' column.
apps_data_copy[~apps_data_copy.Reviews.str.isnumeric()]['Reviews'].index
# Out:
# Int64Index([10472], dtype='int64')

# %%
# Drop the row with index 10472 from 'apps_data_copy'.
apps_data_copy = apps_data_copy.drop(apps_data_copy.index[10472])

# %%
# Create a DataFrame containing rows with non-numeric values in the 'Reviews' column.
apps_data_copy[~apps_data_copy.Reviews.str.isnumeric()]['Reviews'].index
# Out:
# Int64Index([], dtype='int64')

# %%
# Converting Reviews datatype to int 
apps_data_copy['Reviews'] = apps_data_copy['Reviews'].astype(int)

# %%
apps_data_copy['Reviews'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# ### 4.2] Size

# %%
apps_data_copy['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %% [markdown]
# ### <font color=red>Operation:</font>
#
# ### - Remove all characters from size and convert it to float

# %%
# Data Cleaning and Transformation for the 'Size' Column
apps_data_copy['Size']=apps_data_copy['Size'].str.replace('M','000')
apps_data_copy['Size']=apps_data_copy['Size'].str.replace('k','')
apps_data_copy['Size']=apps_data_copy['Size'].replace("Varies with device",np.nan)
apps_data_copy['Size']=apps_data_copy['Size'].astype('float')

# %%
apps_data_copy['Size']
# Out:
# 0         19000.0
# 1         14000.0
# 2             8.7
# 3         25000.0
# 4             2.8
# 5             5.6
# 6         19000.0
# 7         29000.0
# 8         33000.0
# 9             3.1
# 10        28000.0
# 11        12000.0
# 12        20000.0
# 13        21000.0
# 14        37000.0
# 15            2.7
# 16            5.5
# 17        17000.0
# 18        39000.0
# 19        31000.0
# 20        14000.0
# 21        12000.0
# 22            4.2
# 23            7.0
# 24        23000.0
# 25            6.0
# 26        25000.0
# 27            6.1
# 28            4.6
# 29            4.2
# 30            9.2
# 31            5.2
# 32        11000.0
# 33        11000.0
# 34            4.2
# 35            9.2
# 36        24000.0
# 37            NaN
# 38        11000.0
# 39            9.4
# 40        15000.0
# 41        10000.0
# 42            NaN
# 43            1.2
# 44        12000.0
# 45        24000.0
# 46        26000.0
# 47            8.0
# 48            7.9
# 49        25000.0
# ...

# %% [markdown]
# ### <font color=red>Operation:</font>
#
# ### - Convert mega bytes to kilo bytes then convert all to mega bytes.

# %%
for i in apps_data_copy['Size']:
    if i < 10:
        apps_data_copy['Size']=apps_data_copy['Size'].replace(i,i*1000)
apps_data_copy['Size'] = apps_data_copy['Size']/1000
apps_data_copy['Size']
# Out:
# 0         19.000
# 1         14.000
# 2          8.700
# 3         25.000
# 4          2.800
# 5          5.600
# 6         19.000
# 7         29.000
# 8         33.000
# 9          3.100
# 10        28.000
# 11        12.000
# 12        20.000
# 13        21.000
# 14        37.000
# 15         2.700
# 16         5.500
# 17        17.000
# 18        39.000
# 19        31.000
# 20        14.000
# 21        12.000
# 22         4.200
# 23         7.000
# 24        23.000
# 25         6.000
# 26        25.000
# 27         6.100
# 28         4.600
# 29         4.200
# 30         9.200
# 31         5.200
# 32        11.000
# 33        11.000
# 34         4.200
# 35         9.200
# 36        24.000
# 37           NaN
# 38        11.000
# 39         9.400
# 40        15.000
# 41        10.000
# 42           NaN
# 43         1.200
# 44        12.000
# 45        24.000
# 46        26.000
# 47         8.000
# 48         7.900
# 49        25.000
# 50        56.000
# 51        57.000
# ...
